# %%
import pandas as pd
from IPython.display import display

tabela = pd.read_excel('dados_rotes_novos.xlsx')
display(tabela)
# Out:
#      id  starting point          destin  distance  time_days  load_value  \
# 0    r1       São Paulo  Rio de Janeiro       200          3        5000
# 1    r2  Rio de Janeiro  Belo Horizonte       300          4        8000
# 2    r3  Belo Horizonte        Brasília       250          2        6000
# 3    r4        Brasília        Salvador       320          3        7500
# 4    r5        Salvador       Fortaleza       280          4        9000
# 5    r6       Fortaleza        Curitiba       400          2        7000
# 6    r7        Curitiba          Manaus       340          3        8200
# 7    r8          Manaus           Belém       290          4        5500
# 8    r9           Belém    Porto Alegre       380          2        6800
# 9   r10    Porto Alegre       São Paulo       270          3        7200
# 10  r11  Rio de Janeiro        Brasília       310          4        6100
# 11  r12  Belo Horizonte        Salvador       240          2        5300
# ...
